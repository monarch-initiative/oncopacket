# %%
import pandas as pd
from cdapython import tables, columns, column_values, fetch_rows, summary_counts

Query = {'match_any': ['primary_diagnosis_site = *bone*',
                       'primary_diagnosis_site = *osseous*'],
         'data_source': 'GDC'}

subject = fetch_rows( table='subject', match_any=['primary_diagnosis_site = *bone*','primary_diagnosis_site = *osseous*'], provenance=True) # provenance=True

subject.head()
# Out:
#         subject_id cause_of_death days_to_birth days_to_death     ethnicity  \
# 0  ccdi_mci.PBBRIE                      2156436          <NA>  Non-Hispanic
# 1  ccdi_mci.PBBRIE                      2156436          <NA>  Non-Hispanic
# 2  ccdi_mci.PBBRIE                      2156436          <NA>  Non-Hispanic
# 3  ccdi_mci.PBBRIE                      2156436          <NA>  Non-Hispanic
# 4  ccdi_mci.PBBRIE                      2156436          <NA>  Non-Hispanic
#
#                         race     sex species vital_status subject_data_source  \
# 0  Black or African American  female   human                              CDS
# 1  Black or African American  female   human                              CDS
# 2  Black or African American  female   human                              IDC
# 3  Black or African American  female   human                              IDC
# 4  Black or African American  female   human                              IDC
#
#                               subject_data_source_id
# 0                  participant.participant_id:PBBRIE
# 1  participant.uuid:709734fe-2857-5e3c-bfc2-ee9bc...
# 2   idc_case_id:ee88f7f5-2216-41fc-bcae-5599c344df45
# 3                                   PatientID:PBBRIE
# 4                           submitter_case_id:PBBRIE
